# %% [markdown]
# # 06 · 离线 RL 与离线评估（OPE）
#
# 先生成离线日志数据集，再用 IS/DR 的玩具版结构理解 OPE。

# %%
# !python3 ../code/offline/make_offline_dataset.py

# %%
# !python3 ../code/offline/ope_is_dr.py

# %% [markdown]
# 注意：这里的 IS/DR 是‘概念演示’版本，真实场景需要更严谨的概率建模与序列回报处理。
